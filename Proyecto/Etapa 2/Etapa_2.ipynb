# %%
import pandas as pd

# %%
X0=pd.read_parquet('X_t0.parquet')
X1=pd.read_parquet('X_t1.parquet')
X2=pd.read_parquet('X_t2.parquet')
y0=pd.read_parquet('y_t0.parquet')
y1=pd.read_parquet('y_t1.parquet')

# %%
# !pip install optuna
# Out:
# Requirement already satisfied: optuna in c:\users\geral\anaconda3\lib\site-packages (4.0.0)
# Requirement already satisfied: alembic>=1.5.0 in c:\users\geral\anaconda3\lib\site-packages (from optuna) (1.13.3)
# Requirement already satisfied: colorlog in c:\users\geral\anaconda3\lib\site-packages (from optuna) (6.8.2)
# Requirement already satisfied: numpy in c:\users\geral\anaconda3\lib\site-packages (from optuna) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\geral\anaconda3\lib\site-packages (from optuna) (23.2)
# Requirement already satisfied: sqlalchemy>=1.3.0 in c:\users\geral\anaconda3\lib\site-packages (from optuna) (2.0.30)
# Requirement already satisfied: tqdm in c:\users\geral\anaconda3\lib\site-packages (from optuna) (4.66.4)
# Requirement already satisfied: PyYAML in c:\users\geral\anaconda3\lib\site-packages (from optuna) (6.0.1)
# Requirement already satisfied: Mako in c:\users\geral\anaconda3\lib\site-packages (from alembic>=1.5.0->optuna) (1.3.6)
# Requirement already satisfied: typing-extensions>=4 in c:\users\geral\anaconda3\lib\site-packages (from alembic>=1.5.0->optuna) (4.12.2)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\geral\anaconda3\lib\site-packages (from sqlalchemy>=1.3.0->optuna) (3.0.1)
# Requirement already satisfied: colorama in c:\users\geral\anaconda3\lib\site-packages (from colorlog->optuna) (0.4.6)
# Requirement already satisfied: MarkupSafe>=0.9.2 in c:\users\geral\anaconda3\lib\site-packages (from Mako->alembic>=1.5.0->optuna) (2.1.3)

# %%
import optuna
from optuna.visualization import plot_contour
from optuna.visualization import plot_edf
from optuna.visualization import plot_intermediate_values
from optuna.visualization import plot_optimization_history
from optuna.visualization import plot_parallel_coordinate
from optuna.visualization import plot_param_importances
from optuna.visualization import plot_slice
from sklearn.model_selection import train_test_split
from xgboost import XGBClassifier
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler

# %%
ys = ['target']
binary_columns = ['market_ht_trendmode', 'unique_borrow_protocol_count', 'unique_lending_protocol_count']
id_columns = ['borrow_block_number']
wallet = ['wallet_address']
time_columns = [
    'risky_first_tx_timestamp', 'risky_last_tx_timestamp', 'risky_first_last_tx_timestamp_diff',
    'time_since_first_deposit', 'time_since_last_liquidated','borrow_timestamp', 'first_tx_timestamp', 'last_tx_timestamp']

# Columnas a escalar
columns_to_scale = list(X0.columns.difference(id_columns + binary_columns + time_columns + ys + wallet))

# Configurar el preprocesador
preprocessor = ColumnTransformer(
    transformers=[
        ('scaler', StandardScaler(), columns_to_scale),
        ('passthrough', 'passthrough', id_columns + binary_columns + time_columns)
    ]
)

# %%
X_train, X_test, y_train, y_test = train_test_split(X0, y0, test_size=0.3, stratify=y0,random_state=17)

# %%
pipeline = Pipeline([
    ('Preprocessing', preprocessor),
    ('XGBoost', XGBClassifier())
])

pipeline.fit(X_train, y_train)

# %%
X0p = preprocessor.fit_transform(X0)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import average_precision_score
from sklearn.model_selection import train_test_split
import optuna

# Define tu función objetivo para maximizar aucpr
def objective_function(trial):
    # Define los hiperparámetros a optimizar
    params = {
        "n_estimators": trial.suggest_int("n_estimators", 10, 300),
        "max_depth": trial.suggest_int("max_depth", 3, 8),
        "min_samples_split": trial.suggest_int("min_samples_split", 2, 10),
        "min_samples_leaf": trial.suggest_int("min_samples_leaf", 1, 10),
        "max_features": trial.suggest_categorical("max_features", ["sqrt", "log2", None]),
        "bootstrap": trial.suggest_categorical("bootstrap", [True, False])
    }

    # Divide los datos en entrenamiento y validación
    X_train, X_test, y_train, y_test = train_test_split(X0p, y0, test_size=0.3, stratify=y0, random_state=17)

    # Entrena el modelo
    model = RandomForestClassifier(
        random_state=17,
        **params
    )
    
    model.fit(X_train, y_train)
    
    # Realiza predicciones de probabilidad
    y_prob = model.predict_proba(X_test)[:, 1]

    # Calcula aucpr
    aucpr = average_precision_score(y_test, y_prob)

    return aucpr

# %%
study = optuna.create_study(direction="maximize")
study.optimize(objective_function, n_trials=50)
print("Mejores parámetros:")
print(study.best_trial.params)

print(f"Mejor AUC-PR alcanzado: {study.best_trial.value}")
# Out:
# [I 2024-12-05 20:59:51,766] A new study created in memory with name: no-name-475aae2b-a032-499c-bfbc-03c1ac55b2c9
# c:\Users\geral\anaconda3\Lib\site-packages\sklearn\base.py:1474: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# [I 2024-12-05 21

# c:\Users\geral\anaconda3\Lib\site-packages\sklearn\base.py:1474: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# [I 2024-12-05 21:52:00,506] Trial 46 finished with value: 0.9170873847489982 and parameters: {'n_estimators': 114, 'max_depth': 8, 'min_samples_split': 8, 'min_samples_leaf': 8, 'max_features': None, 'bootstrap': True}. Best is trial 35 with value: 0.9176663335114493.
# c:\Users\geral\anaconda3\Lib\site-packages\sklearn\base.py:1474: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# [I 2024-12-05 21:54:41,253] Trial 47 finished with value: 0.8821086921834036 and parameters: {'n_estimators': 154, 'max_depth': 7, 'min_samples_split': 9, 'min_samples_leaf': 8, 'max_features': None, 'bootstrap': False}. Best is trial 35 with value: 0.9176663335114493.
# c:\Users\geral\anaconda3\Lib\site-packages\sklearn\base.py:1474: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# [I 2024-12-05 21:55:57,433] Trial 48 finished with value: 0.9168250855866322 and parameters: {'n_estimators': 95, 'max_depth': 8, 'min_samples_split': 8, 'min_samples_leaf': 9, 'max_features': None, 'bootstrap': True}. Best is trial 35 with value: 0.9176663335114493.
# c:\Users\geral\anaconda3\Lib\site-packages\sklearn\base.py:1474: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# [I 2024-12-05 21:58:08,523] Trial 49 finished with value: 0.9173404952539519 and parameters: {'n_estimators': 168, 'max_depth': 8, 'min_samples_split': 8, 'min_samples_leaf': 8, 'max_features': None, 'bootstrap': True}. Best is trial 35 with value: 0.9176663335114493.
# Mejores parámetros:
# {'n_estimators': 293, 'max_depth': 8, 'min_samples_split': 7, 'min_samples_leaf': 6, 'max_features': None, 'bootstrap': True}
# Mejor AUC-PR alcanzado: 0.9176663335114493

# %%
from sklearn.metrics import average_precision_score
from optuna.integration import XGBoostPruningCallback
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split
import optuna

# Define tu función objetivo para maximizar aucpr
def objective_function(trial):
    # Define los hiperparámetros a optimizar
    params = {
        "objective": "binary:logistic",  # Para clasificación binaria
        "eval_metric": "aucpr",  # Métrica usada durante el entrenamiento
        "max_depth": trial.suggest_int("max_depth", 3, 8),
        "learning_rate": trial.suggest_loguniform("learning_rate", 0.001, 0.1),
        "subsample": trial.suggest_float("subsample", 0.5, 1.0),
        "colsample_bytree": trial.suggest_float("colsample_bytree", 0.5, 1.0),
        "min_child_weight": trial.suggest_int("min_child_weight", 1, 7),
        "gamma": trial.suggest_float("gamma", 0, 1),
        "n_estimators": trial.suggest_int("n_estimators", 10, 300),
    }

    # Divide los datos en entrenamiento y validación
    X_train, X_test, y_train, y_test = train_test_split(X0p, y0, test_size=0.3, stratify=y0, random_state=17)

    # Entrena el modelo
    pruning_callback = XGBoostPruningCallback(trial, observation_key="validation_0-aucpr")  # Cambio de clave

    model = XGBClassifier(seed=17,
        eval_set=[(X_train, y_train), (X_test, y_test)],
        early_stopping_rounds=10,
        callbacks=[pruning_callback], **params)

    # Entrenar el modelo
    model.fit(
        X_train,
        y_train,
        eval_set=[(X_train, y_train), (X_test, y_test)],
        verbose=False
    )
    
    # Realiza predicciones de probabilidad
    y_prob = model.predict_proba(X_test)[:, 1]  # Tomamos la probabilidad de la clase positiva
    
    # Calcula AUC-PR
    aucpr = average_precision_score(y_test, y_prob)
    
    return aucpr

# Crear el estudio Optuna
study = optuna.create_study(direction="maximize")
study.optimize(objective_function, n_trials=200)

# Mostrar los mejores parámetros y AUC-PR alcanzado
print("Mejores parámetros:")
print(study.best_trial.params)

print(f"Mejor AUC-PR alcanzado: {study.best_trial.value}")
# Out:
# [I 2024-12-05 22:10:29,934] A new study created in memory with name: no-name-f423a09f-82cc-49e1-ba32-76f16808176e
# C:\Users\geral\AppData\Local\Temp\ipykernel_448\1409931155.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.001, 0.1),
# c:\Users\geral\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [22:10:30] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "eval_set" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-05 22:10:38,413] Trial 0 finished with value: 0.9654658630472769 and parameters: {'max_depth': 8, 'learning_rate': 0.09337870030465689, 'subsample': 0.7072729983555917, 'colsample_bytree': 0.7264884115076452, 'min_child_weight': 1, 'gamma': 0.9069145536274531, 'n_estimators': 245}. Best is trial 0 with value: 0.9654658630472769.
# C:\Users\geral\AppData\Local\Temp\ipykernel_448\1409931155.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.001, 0.1),
# c:\Users\geral\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [22:10:38] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "eval_set" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-05 22:10:39,381] Trial 1 finished with value: 0.8876095155821412 and parameters: {'max_depth': 4, 'learning_rate': 0.0011823867201554074, 'subsample': 0.6012746888526785, 'colsample_bytree': 0.5064299543445077, 'min_child_weight': 7, 'gamma': 0.4328180569789657, 'n_estimators': 250}. Best is trial 0 with value: 0.9654658630472769.
# C:\Users\geral\AppData\Local\Temp\ipykernel_448\1409931155.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.001, 0.1),
# c:\Users\geral\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [22:10:39] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "eval_set" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-05 22
10] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "eval_set" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-05 22:14:11,908] Trial 189 finished with value: 0.917436239925592 and parameters: {'max_depth': 8, 'learning_rate': 0.0028878331206509847, 'subsample': 0.7024877130217413, 'colsample_bytree': 0.760726418386474, 'min_child_weight': 1, 'gamma': 0.8543602549390303, 'n_estimators': 189}. Best is trial 0 with value: 0.9654658630472769.
# C:\Users\geral\AppData\Local\Temp\ipykernel_448\1409931155.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.001, 0.1),
# c:\Users\geral\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [22:14:12] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "eval_set" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-05 22:14:13,525] Trial 190 finished with value: 0.9178537931429565 and parameters: {'max_depth': 8, 'learning_rate': 0.002931457349660767, 'subsample': 0.7031966859398749, 'colsample_bytree': 0.7540901913694558, 'min_child_weight': 1, 'gamma': 0.8640393121597452, 'n_estimators': 191}. Best is trial 0 with value: 0.9654658630472769.
# C:\Users\geral\AppData\Local\Temp\ipykernel_448\1409931155.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.001, 0.1),
# c:\Users\geral\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [22:14:13] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "eval_set" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-05 22:14:14,868] Trial 191 finished with value: 0.9177028470627966 and parameters: {'max_depth': 8, 'learning_rate': 0.0029206196173600834, 'subsample': 0.7039226483583831, 'colsample_bytree': 0.7565188777442757, 'min_child_weight': 1, 'gamma': 0.8646040715890921, 'n_estimators': 188}. Best is trial 0 with value: 0.9654658630472769.
# C:\Users\geral\AppData\Local\Temp\ipykernel_448\1409931155.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.001, 0.1),
# c:\Users\geral\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [22:14:15] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "eval_set" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-05 22:14:16,201] Trial 192 finished with value: 0.9183273519543004 and parameters: {'max_depth': 8, 'learning_rate': 0.002867283079198842, 'subsample': 0.7048588396730926, 'colsample_bytree': 0.7545094704263903, 'min_child_weight': 1, 'gamma': 0.8614137332638221, 'n_estimators': 189}. Best is trial 0 with value: 0.9654658630472769.
# C:\Users\geral\AppData\Local\Temp\ipykernel_448\1409931155.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.001, 0.1),
# c:\Users\geral\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [22:14:16] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "eval_set" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-05 22:14:17,659] Trial 193 finished with value: 0.9186553475464618 and parameters: {'max_depth': 8, 'learning_rate': 0.0028898455874402486, 'subsample': 0.7053259715126338, 'colsample_bytree': 0.7551859450232346, 'min_child_weight': 1, 'gamma': 0.8559846375816658, 'n_estimators': 191}. Best is trial 0 with value: 0.9654658630472769.
# C:\Users\geral\AppData\Local\Temp\ipykernel_448\1409931155.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.001, 0.1),
# c:\Users\geral\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [22:14:18] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "eval_set" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-05 22:14:18,265] Trial 194 pruned. Trial was pruned at iteration 1.
# C:\Users\geral\AppData\Local\Temp\ipykernel_448\1409931155.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.001, 0.1),
# c:\Users\geral\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [22:14:18] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "eval_set" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-05 22:14:19,196] Trial 195 pruned. Trial was pruned at iteration 9.
# C:\Users\geral\AppData\Local\Temp\ipykernel_448\1409931155.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.001, 0.1),
# c:\Users\geral\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [22:14:19] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "eval_set" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-05 22:14:20,003] Trial 196 pruned. Trial was pruned at iteration 6.
# C:\Users\geral\AppData\Local\Temp\ipykernel_448\1409931155.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.001, 0.1),
# c:\Users\geral\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [22:14:20] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "eval_set" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-05 22:14:20,546] Trial 197 pruned. Trial was pruned at iteration 0.
# C:\Users\geral\AppData\Local\Temp\ipykernel_448\1409931155.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.001, 0.1),
# c:\Users\geral\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [22:14:20] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "eval_set" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-05 22:14:22,083] Trial 198 finished with value: 0.9175727445322813 and parameters: {'max_depth': 8, 'learning_rate': 0.002410661916788037, 'subsample': 0.6875856811391728, 'colsample_bytree': 0.763822577099108, 'min_child_weight': 1, 'gamma': 0.8730685506155159, 'n_estimators': 190}. Best is trial 0 with value: 0.9654658630472769.
# C:\Users\geral\AppData\Local\Temp\ipykernel_448\1409931155.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.001, 0.1),
# c:\Users\geral\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [22:14:22] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "eval_set" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-05 22:14:22,658] Trial 199 pruned. Trial was pruned at iteration 1.
# Mejores parámetros:
# {'max_depth': 8, 'learning_rate': 0.09337870030465689, 'subsample': 0.7072729983555917, 'colsample_bytree': 0.7264884115076452, 'min_child_weight': 1, 'gamma': 0.9069145536274531, 'n_estimators': 245}
# Mejor AUC-PR alcanzado: 0.9654658630472769

# %%
# Definir los hiperparámetros de XGBoost
params = {
    'max_depth': 8,
    'learning_rate': 0.09337870030465689,
    'subsample': 0.7072729983555917,
    'colsample_bytree': 0.7264884115076452,
    'min_child_weight': 1,
    'gamma': 0.9069145536274531,
    'n_estimators': 245
}
# Dividir los datos en entrenamiento y test
X_train, X_test, y_train, y_test = train_test_split(X0, y0, test_size=0.3, stratify=y0, random_state=17)

# Crear el pipeline
pipeline = Pipeline([
    ('Preprocessing', preprocessor),
    ('classifier', XGBClassifier(**params, random_state=17))
])

# Entrenar el modelo
pipeline.fit(X_train, y_train)

# Realizar predicciones de probabilidad
y_prob = pipeline.predict_proba(X_test)[:, 1]

# Calcular la métrica AUC PR
aucpr = average_precision_score(y_test, y_prob)

# Imprimir el resultado
print(f"AUC PR: {aucpr}")
# Out:
# AUC PR: 0.9664470892298799

# %%
import joblib
joblib.dump(pipeline, 'model_v1.pkl')
# Out:
# ['model_v1.pkl']

# %%
# Cargar el modelo guardado
pipeline_new = joblib.load('model_v1.pkl')

# Re-entrenar el modelo con nuevos datos
pipeline_new.fit(X1, y1)

# Realizar nuevas predicciones con el modelo re-entrenado
y_prob_new = pipeline_new.predict_proba(X_test)[:, 1]

# Recalcular la métrica AUC PR después del re-entrenamiento
aucpr_new = average_precision_score(y_test, y_prob_new)
print(f"AUC PR (after re-training): {aucpr_new}")
# Out:
# AUC PR (after re-training): 0.8652992031281962

# %%
X1p = preprocessor.fit_transform(X1)

# %%
# Función objetivo para optimización de hiperparámetros
def objective(trial):
    # Definir los hiperparámetros a optimizar
    params = {
        'max_depth': trial.suggest_int('max_depth', 3, 12),
        'learning_rate': trial.suggest_loguniform('learning_rate', 1e-4, 1e-1),
        'subsample': trial.suggest_float('subsample', 0.5, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.5, 1.0),
        'min_child_weight': trial.suggest_int('min_child_weight', 1, 10),
        'gamma': trial.suggest_float('gamma', 0.0, 1.0),
        'n_estimators': trial.suggest_int('n_estimators', 50, 300),
        'eval_metric': 'aucpr',  # Definir explícitamente la métrica de evaluación
    }

    # Dividir los datos en entrenamiento y test
    X_train, X_test, y_train, y_test = train_test_split(X1p, y1, test_size=0.3, stratify=y1, random_state=17)
    
    # Crear el pruning callback
    pruning_callback = XGBoostPruningCallback(trial, observation_key="validation_0-aucpr")
    
    # Crear el modelo
    model = XGBClassifier(**params, random_state=17, early_stopping_rounds=10, eval_set=[(X_train, y_train), (X_test, y_test)], callbacks=[pruning_callback])

    # Entrenar el modelo
    model.fit(X_train, y_train, eval_set=[(X_train, y_train), (X_test, y_test)], verbose=False)
    
    # Realiza predicciones de probabilidad
    y_prob = model.predict_proba(X_test)[:, 1]  # Tomamos la probabilidad de la clase positiva
    
    # Calcula AUC-PR
    aucpr = average_precision_score(y_test, y_prob)
    
    return aucpr

# Definir el estudio de Optuna
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=200)  # Realiza 200 pruebas de optimización

# Imprimir los mejores parámetros encontrados
print(f"Best hyperparameters: {study.best_params}")
# Out:
# [I 2024-12-05 22:39:44,421] A new study created in memory with name: no-name-c0b9a92b-c073-46ec-a278-1eae272089b3
# C:\Users\geral\AppData\Local\Temp\ipykernel_448\1737294034.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-4, 1e-1),
# c:\Users\geral\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [22:39:45] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "eval_set" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-05 22:40:01,754] Trial 0 finished with value: 0.8951240375354104 and parameters: {'max_depth': 10, 'learning_rate': 0.022481281929030508, 'subsample': 0.9123814456333867, 'colsample_bytree': 0.8400284872217928, 'min_child_weight': 1, 'gamma': 0.7667119597850548, 'n_estimators': 100}. Best is trial 0 with value: 0.8951240375354104.
# C:\Users\geral\AppData\Local\Temp\ipykernel_448\1737294034.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-4, 1e-1),
# c:\Users\geral\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [22:40:02] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "eval_set" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-05 22:40:04,120] Trial 1 finished with value: 0.8348542840687522 and parameters: {'max_depth': 6, 'learning_rate': 0.0006488717576368633, 'subsample': 0.568407899778659, 'colsample_bytree': 0.7824723944681694, 'min_child_weight': 4, 'gamma': 0.0729607482110769, 'n_estimators': 248}. Best is trial 0 with value: 0.8951240375354104.
# C:\Users\geral\AppData\Local\Temp\ipykernel_448\1737294034.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-4, 1e-1),
# c:\Users\geral\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [22:40:05] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "eval_set" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-05 22:40:14,472] Trial 2 finished with value: 0.8827494016119714 and parameters: {'max_depth': 12, 'learning_rate': 0.00012448599239756606, 'subsample': 0.9424108925808576, 'colsample_bytree': 0.8266036021930948, 'min_child_weight': 1, 'gamma': 0.7808800053656215, 'n_estimators': 293}. Best is trial 0 with value: 0.8951240375354104.
# C:\Users\geral\AppData\Local\Temp\ipykernel_448\1737294034.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-4, 1e-1),
# c:\Users\geral\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [22:40:15] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "eval_set" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-05 22:40:19,595] Trial 3 finished with value: 0.8824444745866246 and parameters: {'max_depth': 11, 'learning_rate': 0.0003697921349008392, 'subsample': 0.8613438950828582, 'colsample_bytree': 0.5122457207696673, 'min_child_weight': 3, 'gamma': 0.9023312269429697, 'n_estimators': 172}. Best is trial 0 with value: 0.8951240375354104.
# C:\Users\geral\AppData\Local\Temp\ipykernel_448\1737294034.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-4, 1e-1),
# c:\Users\geral\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [22:40:20] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "eval_set" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-05 22:40:23,220] Trial 4 finished with value: 0.8381622079078139 and parameters: {'max_depth': 7, 'learning_rate': 0.0005151783520216777, 'subsample': 0.7245073545661751, 'colsample_bytree': 0.935001636902357, 'min_child_weight': 4, 'gamma': 0.8433544413420709, 'n_estimators': 208}. Best is trial 0 with value: 0.8951240375354104.
# C:\Users\geral\AppData\Local\Temp\ipykernel_448\1737294034.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-4, 1e-1),
# c:\Users\geral\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [22:40:24] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "eval_set" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-05 22:40:24,684] Trial 5 pruned. Trial was pruned at iteration 0.
# C:\Users\geral\AppData\Local\Temp\ipykernel_448\1737294034.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-4, 1e-1),
# c:\Users\geral\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [22:40:25] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "eval_set" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-05 22:40:25,827] Trial 6 pruned. Trial was pruned at iteration 0.
# C:\Users\geral\AppData\Local\Temp\ipykernel_448\1737294034.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-4, 1e-1),
# c:\Users\geral\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [22:40:26] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "eval_set" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-05 22:40:27,070] Trial 7 pruned. Trial was pruned at iteration 0.
# C:\Users\geral\AppData\Local\Temp\ipykernel_448\1737294034.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-4, 1e-1),
# c:\Users\geral\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [22:40:28] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "eval_set" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-05 22:40:28,239] Trial 8 pruned. Trial was pruned at iteration 0.
# C:\Users\geral\AppData\Local\Temp\ipykernel_448\1737294034.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-4, 1e-1),
# c:\Users\geral\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [22:40:29] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "eval_set" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-05 22:40:33,834] Trial 9 pruned. Trial was pruned at iteration 20.
# C:\Users\geral\AppData\Local\Temp\ipykernel_448\1737294034.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-4, 1e-1),
# c:\Users\geral\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [22:40:35] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "eval_set" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-05 22:40:35,259] Trial 10 pruned. Trial was pruned at iteration 0.
# C:\Users\geral\AppData\Local\Temp\ipykernel_448\1737294034.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-4, 1e-1),
# c:\Users\geral\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [22:40:36] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "eval_set" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-05 22:40:36,907] Trial 11 pruned. Trial was pruned at iteration 2.
# C:\Users\geral\AppData\Local\Temp\ipykernel_448\1737294034.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-4, 1e-1),
# c:\Users\geral\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [22:40:38] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "eval_set" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-05 22:40:44,699] Trial 12 finished with value: 0.8835920648347194 and parameters: {'max_depth': 12, 'learning_rate': 0.0019166602145750356, 'subsample': 0.8163695086537656, 'colsample_bytree': 0.7493882417940358, 'min_child_weight': 1, 'gamma': 0.7510818582092623, 'n_estimators': 135}. Best is trial 0 with value: 0.8951240375354104.
# C:\Users\geral\AppData\Local\Temp\ipykernel_448\1737294034.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-4, 1e-1),
# c:\Users\geral\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [22:40:45] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "eval_set" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-05 22:40:46,020] Trial 13 pruned. Trial was pruned at iteration 0.
# C:\Users\geral\AppData\Local\Temp\ipykernel_448\1737294034.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-4, 1e-1),
# c:\Users\geral\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [22:40:47] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "eval_set" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-05 22:40:47,850] Trial 14 pruned. Trial was pruned at iteration 2.
# C:\Users\geral\AppData\Local\Temp\ipykernel_448\1737294034.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-4, 1e-1),
# c:\Users\geral\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [22:40:49] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "eval_set" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-05 22:40:49,519] Trial 15 pruned. Trial was pruned at iteration 0.
# C:\Users\geral\AppData\Local\Temp\ipykernel_448\1737294034.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-4, 1e-1),
# c:\Users\geral\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [22:40:50] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "eval_set" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-05 22:40:50,803] Trial 16 pruned. Trial was pruned at iteration 0.
# C:\Users\geral\AppData\Local\Temp\ipykernel_448\1737294034.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-4, 1e-1),
# c:\Users\geral\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [22:40:52] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "eval_set" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-05 22:40:52,718] Trial 17 pruned. Trial was pruned at iteration 2.
# C:\Users\geral\AppData\Local\Temp\ipykernel_448\1737294034.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-4, 1e-1),
# c:\Users\geral\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [22:40:53] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "eval_set" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-05 22:41:01,054] Trial 18 finished with value: 0.8821644445065331 and parameters: {'max_depth': 12, 'learning_rate': 0.0009859810389627197, 'subsample': 0.7202244003978971, 'colsample_bytree': 0.7434606239398373, 'min_child_weight': 2, 'gamma': 0.9961159489998277, 'n_estimators': 117}. Best is trial 0 with value: 0.8951240375354104.
# C:\Users\geral\AppData\Local\Temp\ipykernel_448\1737294034.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-4, 1e-1),
# c:\Users\geral\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [22:41:02] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "eval_set" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-05 22:41:02,676] Trial 19 pruned. Trial was pruned at iteration 1.
# C:\Users\geral\AppData\Local\Temp\ipykernel_448\1737294034.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-4, 1e-1),
# c:\Users\geral\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [22:41:03] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "eval_set" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-05 22:41:03,960] Trial 20 pruned. Trial was pruned at iteration 0.
# C:\Users\geral\AppData\Local\Temp\ipykernel_448\1737294034.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-4, 1e-1),
# c:\Users\geral\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [22:41:05] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "eval_set" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-05 22:41:24,988] Trial 21 pruned. Trial was pruned at iteration 72.
# C:\Users\geral\AppData\Local\Temp\ipykernel_448\1737294034.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-4, 1e-1),
# c:\Users\geral\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [22:41:26] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "eval_set" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-05 22:42:22,205] Trial 22 finished with value: 0.9006787323495558 and parameters: {'max_depth': 12, 'learning_rate': 0.004464053126551792, 'subsample': 0.9643579873823503, 'colsample_bytree': 0.8210189659438603, 'min_child_weight': 2, 'gamma': 0.8913286369138279, 'n_estimators': 247}. Best is trial 22 with value: 0.9006787323495558.
# C:\Users\geral\AppData\Local\Temp\ipykernel_448\1737294034.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-4, 1e-1),
# c:\Users\geral\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [22:42:23] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "eval_set" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-05 22:42:24,163] Trial 23 pruned. Trial was pruned at iteration 2.
# C:\Users\geral\AppData\Local\Temp\ipykernel_448\1737294034.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-4, 1e-1),
# c:\Users\geral\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [22:42:25] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "eval_set" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-05 22:42:25,644] Trial 24 pruned. Trial was pruned at iteration 0.
# C:\Users\geral\AppData\Local\Temp\ipykernel_448\1737294034.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-4, 1e-1),
# c:\Users\geral\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [22:42:26] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "eval_set" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-05 22:42:27,160] Trial 25 pruned. Trial was pruned at iteration 0.
# C:\Users\geral\AppData\Local\Temp\ipykernel_448\1737294034.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-4, 1e-1),
# c:\Users\geral\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [22:42:28] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "eval_set" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-05 22:42:33,243] Trial 26 finished with value: 0.8845243633046755 and parameters: {'max_depth': 12, 'learning_rate': 0.0020104895819977866, 'subsample': 0.9689711993855042, 'colsample_bytree': 0.7546661568630754, 'min_child_weight': 2, 'gamma': 0.5713454265220146, 'n_estimators': 227}. Best is trial 22 with value: 0.9006787323495558.
# C:\Users\geral\AppData\Local\Temp\ipykernel_448\1737294034.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-4, 1e-1),
# c:\Users\geral\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [22:42:34] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "eval_set" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-05 22:42:35,058] Trial 27 pruned. Trial was pruned at iteration 1.
# C:\Users\geral\AppData\Local\Temp\ipykernel_448\1737294034.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-4, 1e-1),
# c:\Users\geral\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [22:42:36] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "eval_set" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-05 22:42:36,576] Trial 28 pruned. Trial was pruned at iteration 0.
# C:\Users\geral\AppData\Local\Temp\ipykernel_448\1737294034.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-4, 1e-1),
# c:\Users\geral\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [22:42:37] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "eval_set" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-05 22:43:12,972] Trial 29 finished with value: 0.9220291687022895 and parameters: {'max_depth': 12, 'learning_rate': 0.026165521492358113, 'subsample': 0.9592940424638234, 'colsample_bytree': 0.7782176720196773, 'min_child_weight': 4, 'gamma': 0.5527343441062912, 'n_estimators': 232}. Best is trial 29 with value: 0.9220291687022895.
# C:\Users\geral\AppData\Local\Temp\ipykernel_448\1737294034.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-4, 1e-1),
# c:\Users\geral\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [22:43:14] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "eval_set" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-05 22:43:14,387] Trial 30 pruned. Trial was pruned at iteration 0.
# C:\Users\geral\AppData\Local\Temp\ipykernel_448\1737294034.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-4, 1e-1),
# c:\Users\geral\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [22:43:15] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "eval_set" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-05 22:43:58,538] Trial 31 finished with value: 0.9162460526705757 and parameters: {'max_depth': 12, 'learning_rate': 0.014740044777489747, 'subsample': 0.9698095860605905, 'colsample_bytree': 0.7778933117022447, 'min_child_weight': 3, 'gamma': 0.6335440808098414, 'n_estimators': 236}. Best is trial 29 with value: 0.9220291687022895.
# C:\Users\geral\AppData\Local\Temp\ipykernel_448\1737294034.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-4, 1e-1),
# c:\Users\geral\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [22:43:59] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "eval_set" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-05 22:44:00,379] Trial 32 pruned. Trial was pruned at iteration 0.
# C:\Users\geral\AppData\Local\Temp\ipykernel_448\1737294034.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-4, 1e-1),
# c:\Users\geral\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [22:44:01] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "eval_set" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-05 22:44:01,887] Trial 33 pruned. Trial was pruned at iteration 0.
# C:\Users\geral\AppData\Local\Temp\ipykernel_448\1737294034.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-4, 1e-1),
# c:\Users\geral\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [22:44:03] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "eval_set" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-05 22:44:03,642] Trial 34 pruned. Trial was pruned at iteration 0.
# C:\Users\geral\AppData\Local\Temp\ipykernel_448\1737294034.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-4, 1e-1),
# c:\Users\geral\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [22:44:04] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "eval_set" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-05 22:44:05,363] Trial 35 pruned. Trial was pruned at iteration 0.
# C:\Users\geral\AppData\Local\Temp\ipykernel_448\1737294034.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-4, 1e-1),
# c:\Users\geral\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [22:44:06] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "eval_set" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-05 22:44:06,534] Trial 36 pruned. Trial was pruned at iteration 0.
# C:\Users\geral\AppData\Local\Temp\ipykernel_448\1737294034.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-4, 1e-1),
# c:\Users\geral\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [22:44:07] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "eval_set" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-05 22:44:07,794] Trial 37 pruned. Trial was pruned at iteration 0.
# C:\Users\geral\AppData\Local\Temp\ipykernel_448\1737294034.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-4, 1e-1),
# c:\Users\geral\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [22:44:09] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "eval_set" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-05 22:44:09,422] Trial 38 pruned. Trial was pruned at iteration 0.
# C:\Users\geral\AppData\Local\Temp\ipykernel_448\1737294034.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-4, 1e-1),
# c:\Users\geral\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [22:44:10] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "eval_set" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-05 22:44:11,027] Trial 39 pruned. Trial was pruned at iteration 0.
# C:\Users\geral\AppData\Local\Temp\ipykernel_448\1737294034.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-4, 1e-1),
# c:\Users\geral\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [22:44:12] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "eval_set" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-05 22:44:13,246] Trial 40 pruned. Trial was pruned at iteration 1.
# C:\Users\geral\AppData\Local\Temp\ipykernel_448\1737294034.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-4, 1e-1),
# c:\Users\geral\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [22:44:14] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "eval_set" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-05 22:44:22,410] Trial 41 finished with value: 0.8860150237669094 and parameters: {'max_depth': 12, 'learning_rate': 0.00050315754283901, 'subsample': 0.9606428866125263, 'colsample_bytree': 0.7246256103315185, 'min_child_weight': 2, 'gamma': 0.5458992961629406, 'n_estimators': 226}. Best is trial 29 with value: 0.9220291687022895.
# C:\Users\geral\AppData\Local\Temp\ipykernel_448\1737294034.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-4, 1e-1),
# c:\Users\geral\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [22:44:23] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "eval_set" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-05 22:44:29,298] Trial 42 finished with value: 0.8881705175188326 and parameters: {'max_depth': 12, 'learning_rate': 0.00021520441133763844, 'subsample': 0.9526294046050671, 'colsample_bytree': 0.7229725188966445, 'min_child_weight': 2, 'gamma': 0.5345994318686413, 'n_estimators': 242}. Best is trial 29 with value: 0.9220291687022895.
# C:\Users\geral\AppData\Local\Temp\ipykernel_448\1737294034.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-4, 1e-1),
# c:\Users\geral\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [22:44:30] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "eval_set" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-05 22:44:30,673] Trial 43 pruned. Trial was pruned at iteration 0.
# C:\Users\geral\AppData\Local\Temp\ipykernel_448\1737294034.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-4, 1e-1),
# c:\Users\geral\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [22:44:31] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "eval_set" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-05 22:44:33,174] Trial 44 pruned. Trial was pruned at iteration 3.
# C:\Users\geral\AppData\Local\Temp\ipykernel_448\1737294034.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-4, 1e-1),
# c:\Users\geral\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [22:44:34] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "eval_set" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-05 22:44:34,816] Trial 45 pruned. Trial was pruned at iteration 0.
# C:\Users\geral\AppData\Local\Temp\ipykernel_448\1737294034.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-4, 1e-1),
# c:\Users\geral\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [22:44:36] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "eval_set" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-05 22:44:36,818] Trial 46 pruned. Trial was pruned at iteration 0.
# C:\Users\geral\AppData\Local\Temp\ipykernel_448\1737294034.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-4, 1e-1),
# c:\Users\geral\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [22:44:37] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "eval_set" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-05 22:44:38,208] Trial 47 pruned. Trial was pruned at iteration 0.
# C:\Users\geral\AppData\Local\Temp\ipykernel_448\1737294034.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-4, 1e-1),
# c:\Users\geral\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [22:44:39] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "eval_set" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-05 22:44:39,736] Trial 48 pruned. Trial was pruned at iteration 0.
# C:\Users\geral\AppData\Local\Temp\ipykernel_448\1737294034.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-4, 1e-1),
# c:\Users\geral\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [22:44:41] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "eval_set" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-05 22:44:41,349] Trial 49 pruned. Trial was pruned at iteration 0.
# C:\Users\geral\AppData\Local\Temp\ipykernel_448\1737294034.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-4, 1e-1),
# c:\Users\geral\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [22:44:42] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "eval_set" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-05 22:44:43,267] Trial 50 pruned. Trial was pruned at iteration 0.
# C:\Users\geral\AppData\Local\Temp\ipykernel_448\1737294034.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-4, 1e-1),
# c:\Users\geral\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [22:44:44] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "eval_set" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-05 22:44:49,873] Trial 51 finished with value: 0.8840339601128966 and parameters: {'max_depth': 12, 'learning_rate': 0.00017191181965717995, 'subsample': 0.962175973492735, 'colsample_bytree': 0.778276715152987, 'min_child_weight': 2, 'gamma': 0.5493287600256734, 'n_estimators': 229}. Best is trial 29 with value: 0.9220291687022895.
# C:\Users\geral\AppData\Local\Temp\ipykernel_448\1737294034.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-4, 1e-1),
# c:\Users\geral\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [22:44:51] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "eval_set" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-05 22:44:58,300] Trial 52 finished with value: 0.8876787564210568 and parameters: {'max_depth': 12, 'learning_rate': 0.0003557861710817071, 'subsample': 0.9486935470450525, 'colsample_bytree': 0.7200116960934941, 'min_child_weight': 2, 'gamma': 0.6067986172894972, 'n_estimators': 220}. Best is trial 29 with value: 0.9220291687022895.
# C:\Users\geral\AppData\Local\Temp\ipykernel_448\1737294034.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-4, 1e-1),
# c:\Users\geral\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [22:44:59] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "eval_set" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-05 22:44:59,857] Trial 53 pruned. Trial was pruned at iteration 0.
# C:\Users\geral\AppData\Local\Temp\ipykernel_448\1737294034.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-4, 1e-1),
# c:\Users\geral\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [22:45:00] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "eval_set" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-05 22:45:09,953] Trial 54 finished with value: 0.8874454832228467 and parameters: {'max_depth': 12, 'learning_rate': 0.0007707485170913807, 'subsample': 0.9381949994560034, 'colsample_bytree': 0.731742007230032, 'min_child_weight': 1, 'gamma': 0.6710853139912141, 'n_estimators': 253}. Best is trial 29 with value: 0.9220291687022895.
# C:\Users\geral\AppData\Local\Temp\ipykernel_448\1737294034.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-4, 1e-1),
# c:\Users\geral\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [22:45:11] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "eval_set" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-05 22:45:11,472] Trial 55 pruned. Trial was pruned at iteration 0.
# C:\Users\geral\AppData\Local\Temp\ipykernel_448\1737294034.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-4, 1e-1),
# c:\Users\geral\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [22:45:12] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "eval_set" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-05 22:45:13,306] Trial 56 pruned. Trial was pruned at iteration 0.
# C:\Users\geral\AppData\Local\Temp\ipykernel_448\1737294034.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-4, 1e-1),
# c:\Users\geral\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [22:45:14] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "eval_set" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-05 22:45:14,766] Trial 57 pruned. Trial was pruned at iteration 0.
# C:\Users\geral\AppData\Local\Temp\ipykernel_448\1737294034.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-4, 1e-1),
# c:\Users\geral\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [22:45:15] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "eval_set" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-05 22:45:16,258] Trial 58 pruned. Trial was pruned at iteration 0.
# C:\Users\geral\AppData\Local\Temp\ipykernel_448\1737294034.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-4, 1e-1),
# ...
# Parameters: { "eval_set" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-05 22:57:19,979] Trial 186 pruned. Trial was pruned at iteration 0.
# C:\Users\geral\AppData\Local\Temp\ipykernel_448\1737294034.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-4, 1e-1),
# c:\Users\geral\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [22:57:21] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "eval_set" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-05 22:57:21,692] Trial 187 pruned. Trial was pruned at iteration 0.
# C:\Users\geral\AppData\Local\Temp\ipykernel_448\1737294034.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-4, 1e-1),
# c:\Users\geral\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [22:57:22] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "eval_set" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-05 22:57:23,152] Trial 188 pruned. Trial was pruned at iteration 0.
# C:\Users\geral\AppData\Local\Temp\ipykernel_448\1737294034.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-4, 1e-1),
# c:\Users\geral\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [22:57:24] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "eval_set" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-05 22:57:24,922] Trial 189 pruned. Trial was pruned at iteration 0.
# C:\Users\geral\AppData\Local\Temp\ipykernel_448\1737294034.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-4, 1e-1),
# c:\Users\geral\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [22:57:26] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "eval_set" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-05 22:57:26,578] Trial 190 pruned. Trial was pruned at iteration 0.
# C:\Users\geral\AppData\Local\Temp\ipykernel_448\1737294034.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-4, 1e-1),
# c:\Users\geral\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [22:57:27] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "eval_set" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-05 22:57:48,000] Trial 191 finished with value: 0.9110285094424728 and parameters: {'max_depth': 12, 'learning_rate': 0.02237075974756469, 'subsample': 0.9825971008577024, 'colsample_bytree': 0.6939103448972359, 'min_child_weight': 1, 'gamma': 0.49594259756905634, 'n_estimators': 87}. Best is trial 175 with value: 0.9312280288392341.
# C:\Users\geral\AppData\Local\Temp\ipykernel_448\1737294034.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-4, 1e-1),
# c:\Users\geral\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [22:57:49] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "eval_set" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-05 22:58:08,976] Trial 192 finished with value: 0.9107496030994429 and parameters: {'max_depth': 12, 'learning_rate': 0.02288218128230482, 'subsample': 0.9827977084777335, 'colsample_bytree': 0.6888173736089268, 'min_child_weight': 1, 'gamma': 0.49161639039962246, 'n_estimators': 84}. Best is trial 175 with value: 0.9312280288392341.
# C:\Users\geral\AppData\Local\Temp\ipykernel_448\1737294034.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-4, 1e-1),
# c:\Users\geral\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [22:58:10] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "eval_set" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-05 22:58:18,591] Trial 193 pruned. Trial was pruned at iteration 32.
# C:\Users\geral\AppData\Local\Temp\ipykernel_448\1737294034.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-4, 1e-1),
# c:\Users\geral\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [22:58:19] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "eval_set" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-05 22:58:28,205] Trial 194 pruned. Trial was pruned at iteration 32.
# C:\Users\geral\AppData\Local\Temp\ipykernel_448\1737294034.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-4, 1e-1),
# c:\Users\geral\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [22:58:29] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "eval_set" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-05 22:58:29,949] Trial 195 pruned. Trial was pruned at iteration 0.
# C:\Users\geral\AppData\Local\Temp\ipykernel_448\1737294034.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-4, 1e-1),
# c:\Users\geral\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [22:58:31] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "eval_set" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-05 22:58:31,695] Trial 196 pruned. Trial was pruned at iteration 0.
# C:\Users\geral\AppData\Local\Temp\ipykernel_448\1737294034.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-4, 1e-1),
# c:\Users\geral\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [22:58:32] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "eval_set" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-05 22:58:33,808] Trial 197 pruned. Trial was pruned at iteration 1.
# C:\Users\geral\AppData\Local\Temp\ipykernel_448\1737294034.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-4, 1e-1),
# c:\Users\geral\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [22:58:34] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "eval_set" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-05 22:58:35,431] Trial 198 pruned. Trial was pruned at iteration 0.
# C:\Users\geral\AppData\Local\Temp\ipykernel_448\1737294034.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-4, 1e-1),
# c:\Users\geral\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [22:58:36] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "eval_set" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-12-05 22:58:45,446] Trial 199 pruned. Trial was pruned at iteration 32.
# Best hyperparameters: {'max_depth': 12, 'learning_rate': 0.027125110612932147, 'subsample': 0.9707007698097644, 'colsample_bytree': 0.6918333714346909, 'min_child_weight': 1, 'gamma': 0.4746767211591132, 'n_estimators': 270}
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File c:\Users\geral\anaconda3\Lib\site-packages\sklearn\utils\__init__.py:482, in _get_column_indices(X, key)
#     481 try:
# --> 482     all_columns = X.columns
#     483 except AttributeError:
#
# AttributeError: 'numpy.ndarray' object has no attribute 'columns'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[68], line 50
#      44 pipeline = Pipeline([
#      45     ('Preprocessing', preprocessor),
#      46     ('classifier', XGBClassifier(**best_params, random_state=17))
#      47 ])
#      49 # Entrenamiento final
# ---> 50 pipeline.fit(X1p, y1)
#      52 # Guardar el modelo reentrenado
#      53 joblib.dump(pipeline, 'model_retrained.pkl')
#
# File c:\Users\geral\anaconda3\Lib\site-packages\sklearn\base.py:1474, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1467     estimator._validate_params()
#    1469 with config_context(
#    1470     skip_parameter_validation=(
#    1471         prefer_skip_nested_validation or global_skip_validation
#    1472     )
#    1473 ):
# -> 1474     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\geral\anaconda3\Lib\site-packages\sklearn\pipeline.py:471, in Pipeline.fit(self, X, y, **params)
#     428 """Fit the model.
#     429
#     430 Fit all the transformers one after the other and sequentially transform the
#    (...)
#     468     Pipeline with fitted steps.
#     469 """
#     470 routed_params = self._check_method_params(method="fit", props=params)
# --> 471 Xt = self._fit(X, y, routed_params)
#     472 with _print_elapsed_time("Pipeline", self._log_message(len(self.steps) - 1)):
#     473     if self._final_estimator != "passthrough":
#
# File c:\Users\geral\anaconda3\Lib\site-packages\sklearn\pipeline.py:408, in Pipeline._fit(self, X, y, routed_params)
#     406     cloned_transformer = clone(transformer)
#     407 # Fit or load from cache the current transformer
# --> 408 X, fitted_transformer = fit_transform_one_cached(
#     409     cloned_transformer,
#     410     X,
#     411     y,
#     412     None,
#     413     message_clsname="Pipeline",
#     414     message=self._log_message(step_idx),
#     415     params=routed_params[name],
#     416 )
#     417 # Replace the transformer of the step with the fitted
#     418 # transformer. This is necessary when loading the transformer
#     419 # from the cache.
#     420 self.steps[step_idx] = (name, fitted_transformer)
#
# File c:\Users\geral\anaconda3\Lib\site-packages\joblib\memory.py:353, in NotMemorizedFunc.__call__(self, *args, **kwargs)
#     352 def __call__(self, *args, **kwargs):
# --> 353     return self.func(*args, **kwargs)
#
# File c:\Users\geral\anaconda3\Lib\site-packages\sklearn\pipeline.py:1303, in _fit_transform_one(transformer, X, y, weight, message_clsname, message, params)
#    1301 with _print_elapsed_time(message_clsname, message):
#    1302     if hasattr(transformer, "fit_transform"):
# -> 1303         res = transformer.fit_transform(X, y, **params.get("fit_transform", {}))
#    1304     else:
#    1305         res = transformer.fit(X, y, **params.get("fit", {})).transform(
#    1306             X, **params.get("transform", {})
#    1307         )
#
# File c:\Users\geral\anaconda3\Lib\site-packages\sklearn\utils\_set_output.py:295, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     293 @wraps(f)
#     294 def wrapped(self, X, *args, **kwargs):
# --> 295     data_to_wrap = f(self, X, *args, **kwargs)
#     296     if isinstance(data_to_wrap, tuple):
#     297         # only wrap the first output for cross decomposition
#     298         return_tuple = (
#     299             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     300             *data_to_wrap[1:],
#     301         )
#
# File c:\Users\geral\anaconda3\Lib\site-packages\sklearn\base.py:1474, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1467     estimator._validate_params()
#    1469 with config_context(
#    1470     skip_parameter_validation=(
#    1471         prefer_skip_nested_validation or global_skip_validation
#    1472     )
#    1473 ):
# -> 1474     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\geral\anaconda3\Lib\site-packages\sklearn\compose\_column_transformer.py:906, in ColumnTransformer.fit_transform(self, X, y, **params)
#     903 self._validate_transformers()
#     904 n_samples = _num_samples(X)
# --> 906 self._validate_column_callables(X)
#     907 self._validate_remainder(X)
#     909 if _routing_enabled():
#
# File c:\Users\geral\anaconda3\Lib\site-packages\sklearn\compose\_column_transformer.py:496, in ColumnTransformer._validate_column_callables(self, X)
#     494         columns = columns(X)
#     495     all_columns.append(columns)
# --> 496     transformer_to_input_indices[name] = _get_column_indices(X, columns)
#     498 self._columns = all_columns
#     499 self._transformer_to_input_indices = transformer_to_input_indices
#
# File c:\Users\geral\anaconda3\Lib\site-packages\sklearn\utils\__init__.py:484, in _get_column_indices(X, key)
#     482     all_columns = X.columns
#     483 except AttributeError:
# --> 484     raise ValueError(
#     485         "Specifying the columns using strings is only supported for dataframes."
#     486     )
#     487 if isinstance(key, str):
#     488     columns = [key]
#
# ValueError: Specifying the columns using strings is only supported for dataframes.

# %%
# Entrenar el modelo final con los mejores parámetros
best_params = study.best_params
pipeline = Pipeline([
    ('Preprocessing', preprocessor),
    ('classifier', XGBClassifier(**best_params, random_state=17))
])

# Entrenamiento final
pipeline.fit(X_train, y_train)

# Guardar el modelo reentrenado
joblib.dump(pipeline, 'model_retrained.pkl')
# Out:
# ['model_retrained.pkl']

# %%
y_prob_new2 = pipeline.predict_proba(X_test)[:, 1]

# Recalcular la métrica AUC PR después del re-entrenamiento
aucpr_new = average_precision_score(y_test, y_prob_new2)
print(f"AUC PR (after re-training): {aucpr_new}")
# Out:
# AUC PR (after re-training): 0.964391042642574

# %% [markdown]
# # Exportar para codalab

# %%
from zipfile import ZipFile
import os
def generateFiles(predict_data, clf_pipe):
    """Genera los archivos a subir en CodaLab

    Input
    ---------------
    predict_data: Dataframe con los datos de entrada a predecir
    clf_pipe: pipeline del clf

    Ouput
    ---------------
    archivo de txt
    """
    y_pred_clf = clf_pipe.predict_proba(predict_data)[:, 1]
    with open('./predictions.txt', 'w') as f:
        for item in y_pred_clf:
            f.write("%s\n" % item)
    
    with ZipFile('predictions.zip', 'w') as zipObj:
        zipObj.write('predictions.txt')
    os.remove('predictions.txt')

generateFiles(X2, pipeline)
